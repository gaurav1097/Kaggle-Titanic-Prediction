# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sklearn 
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_1 = data_train.copy(deep = True)
data_clean = [data_1,data_test]
data_clean
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  5              6         0       3
#  6              7         0       1
#  7              8         0       3
#  8              9         1       3
#  9             10         1       2
#  10            11         1       3
#  11            12         1       1
#  12            13         0       3
#  13            14         0       3
#  14            15         0       3
#  15            16         1       2
#  16            17         0       3
#  17            18         1       2
#  18            19         0       3
#  19            20         1       3
#  20            21         0       2
#  21            22         1       2
#  22            23         1       3
#  23            24         1       1
#  24            25         0       3
# ...

# %%
data_train.describe( include = 'all' )
# Out:
#         PassengerId    Survived      Pclass                Name   Sex  \
# count    891.000000  891.000000  891.000000                 891   891
# unique          NaN         NaN         NaN                 891     2
# top             NaN         NaN         NaN  Bourke, Miss. Mary  male
# freq            NaN         NaN         NaN                   1   577
# mean     446.000000    0.383838    2.308642                 NaN   NaN
# std      257.353842    0.486592    0.836071                 NaN   NaN
# min        1.000000    0.000000    1.000000                 NaN   NaN
# 25%      223.500000    0.000000    2.000000                 NaN   NaN
# 50%      446.000000    0.000000    3.000000                 NaN   NaN
# 75%      668.500000    1.000000    3.000000                 NaN   NaN
# max      891.000000    1.000000    3.000000                 NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare Cabin Embarked
# ...

# %%
for dataset in data_clean: 
    dataset['Age'].fillna(dataset['Age'].mean(), inplace = True)
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)
    dataset['Fare'].fillna(dataset['Fare'].mean(), inplace = True)

dp_col = ['PassengerId','Cabin', 'Ticket']
data_1.drop(dp_col, axis=1, inplace = True)
data_1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
for dataset in data_clean:
    dataset['FamilySize'] = dataset ['SibSp'] + dataset['Parch'] + 1
    dataset['IsAlone'] = 1 
    dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0
    dataset['Title'] = dataset['Name'].str.split(",", expand=True)[1].str.split(".", expand=True)[0]
    dataset['FareBin'] = pd.qcut(dataset['Fare'], 4)
    dataset['AgeBin'] = pd.cut(dataset['Age'].astype(int), 5)
    
stat_min = 10
#title_names = (data_1['Title'].value_counts() < stat_min)    
#data_1['Title'] = data_1['Title'].apply(lambda x: 'Misc' if title_names.loc[x] == True else x)

#title_name = (data_test['Title'].value_counts() < stat_min)    
#data_test['Title'] = data_test['Title'].apply(lambda x: 'Misc' if title_name.loc[x] == True else x)
print(data_1['Title'].value_counts())
# Out:
#  Mr              517
#  Miss            182
#  Mrs             125
#  Master           40
#  Dr                7
#  Rev               6
#  Mlle              2
#  Major             2
#  Col               2
#  Lady              1
#  Ms                1
#  Jonkheer          1
#  the Countess      1
#  Sir               1
#  Don               1
#  Mme               1
#  Capt              1
# Name: Title, dtype: int64
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data_1.sample(10)
# Out:
#      Survived  Pclass                                       Name     Sex  \
# 614         0       3            Brocklebank, Mr. William Alfred    male
# 763         1       1  Carter, Mrs. William Ernest (Lucile Polk)  female
# 368         1       3                        Jermyn, Miss. Annie  female
# 159         0       3                 Sage, Master. Thomas Henry    male
# 466         0       2                      Campbell, Mr. William    male
# 75          0       3                    Moen, Mr. Sigurd Hansen    male
# 501         0       3                        Canavan, Miss. Mary  female
# 223         0       3                       Nenkoff, Mr. Christo    male
# 327         1       2                    Ball, Mrs. (Ada E Hall)  female
# 802         1       1        Carter, Master. William Thornton II    male
#
#            Age  SibSp  Parch      Fare Embarked  FamilySize  IsAlone    Title  \
# 614  35.000000      0      0    8.0500        S           1        1       Mr
# ...

# %%
label = LabelEncoder()
for dataset in data_clean:    
    dataset['Sex_Code'] = label.fit_transform(dataset['Sex'])
    dataset['Embarked_Code'] = label.fit_transform(dataset['Embarked'])
    dataset['Title_Code'] = label.fit_transform(dataset['Title'])
    dataset['AgeBin_Code'] = label.fit_transform(dataset['AgeBin'])
    dataset['FareBin_Code'] = label.fit_transform(dataset['FareBin'])

data_1_x = ['Sex','Pclass', 'Embarked', 'Title','SibSp', 'Parch', 'Age', 'Fare', 'FamilySize', 'IsAlone'] 
data1_dummy = pd.get_dummies(data_1[data_1_x])
data2_dummy = pd.get_dummies(data_test[data_1_x])
coln = ['Pclass','SibSp','Parch','Age','Fare','FamilySize','IsAlone','Sex_female','Sex_male','Embarked_C','Embarked_Q','Embarked_S','Title_ Master','Title_ Miss','Title_ Mr','Title_ Mrs','Title_ Col','Title_ Dr','Title_ Ms','Title_ Rev']
data_1n_d = data1_dummy[coln]
#colm = ['Title_ Dona']
#data_2n_d = data2_dummy.drop('Title_ Dona',inplace = True)
data_2n_d = data2_dummy[coln]
#data2_dummy
data1_dummy
# Out:
#      Pclass  SibSp  Parch        Age      Fare  FamilySize  IsAlone  \
# 0         3      1      0  22.000000    7.2500           2        0
# 1         1      1      0  38.000000   71.2833           2        0
# 2         3      0      0  26.000000    7.9250           1        1
# 3         1      1      0  35.000000   53.1000           2        0
# 4         3      0      0  35.000000    8.0500           1        1
# 5         3      0      0  29.699118    8.4583           1        1
# 6         1      0      0  54.000000   51.8625           1        1
# 7         3      3      1   2.000000   21.0750           5        0
# 8         3      0      2  27.000000   11.1333           3        0
# 9         2      1      0  14.000000   30.0708           2        0
# 10        3      1      1   4.000000   16.7000           3        0
# 11        1      0      0  58.000000   26.5500           1        1
# 12        3      0      0  20.000000    8.0500           1        1
# ...

# %%
# Out:
# 0.8372615039281706

# %%
from sklearn.svm import SVC
svm = SVC()
svm= svm.fit(x_train, y_train)
pre_svm = svm.predict(x_test)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
gbm = xgb.XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.05).fit(train_X, train_y)
predictions = gbm.predict(test_X)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_s = scaler.fit_transform(x_train)
X_test_s = scaler.transform(x_test)
knn = KNeighborsClassifier(n_neighbors = 2)
knn = knn.fit(X_train_s, y_train)
pred_knn = knn.predict(X_test_s)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg = lg.fit(x_train, y_train)
pred = lg.predict(x_test)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
submission = pd.DataFrame({"PassengerId": data_test["PassengerId"],"Survived": Y_pred})
submission.to_csv('titanic_n.csv', index=None)
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...
